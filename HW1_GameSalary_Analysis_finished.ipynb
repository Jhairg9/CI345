# %% [markdown]
# # CI345 HW 1 ( 40 pts)
#
# # Name: Jhair Morales Gonzalez
#
# #Date:04/16/26

# %% [markdown]
# ### Part A. Python Programming

# %%
# Python Programming 

# List and function
# Finish a function to user enter quarterly sales amount.
# Finish a function to display sales
# In main function, invoke above functions and show the total and average sales
# Show the result as the example

QUARTER =["Spring", "Summer", "Fall", "Winter"]
           
def main():
    # create a list to hold the sales of four quarters 
    sales =[0.0] * len(QUARTER)

    inputSales(sales)
    
    print('\nDisplay the quartely sales')
    display (sales)
    
    print('\nDisplay the summary')
    print('Total sales:              $', sum(sales))
    print('Average quarterly sales   $', sum(sales)/len(QUARTER))

# Ask user to enter sales:
def inputSales(sales):
    for i in range(0, len(sales)):
        print('Enter the sales of', QUARTER[i] ,  ' : $' , end = ' ')
        sales[i] = float(input())

# 1) Finish the method here:
def inputSales(sales):
    for i in range(0,len(sales)):
        print('Enter the sales of', QUARTER[i], ':$', end = ' ')
        sales [i] = float(input())
def display(sales):
    for i in range(len(sales)):
        print(sales[i])
        
# Invoke 
main()
# Out:
# Enter the sales of Spring :$
#  9
# Enter the sales of Summer :$
#  0
# Enter the sales of Fall :$
#  99
# Enter the sales of Winter :$
#  999
# Display the quartely sales
# 9.0
# 0.0
# 99.0
# 999.0
#
# Display the summary
# Total sales:              $ 1107.0
# Average quarterly sales   $ 276.75

# %% [markdown]
# ### Part B: Game Salary Data  Analysis

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
# limiting the display rows
pd.set_option('display.max_rows', 8)

# %%
gameSalary = pd.read_csv('data/GameSalary.csv')

# %%
# 2) Show gameSalary number of rows and columns
print("Jhair Morales Gonzalez")
print(gameSalary.shape)
# Out:
# Jhair Morales Gonzalez
# (93, 8)

# %%
# 3) display all column name
print("Jhair Morales Gonzalez")
print(gameSalary.columns)
# Out:
# Jhair Morales Gonzalez
# Index(['ID', 'Last Name', 'First Name', 'Gender', 'Department', 'Title',
#        'Salary', 'Performance'],
#       dtype='object')

# %%
names = gameSalary.columns
for name in names:
    print(name)
# Out:
# ID
# Last Name
# First Name
# Gender
# Department
# Title
# Salary
# Performance

# %%
# 4) show the first three record
print("Jhair Morales Gonzalez")
gameSalary.head(3)
# Out:
# Jhair Morales Gonzalez
#       ID Last Name First Name Gender    Department                  Title  \
# 0  10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1  10387    Felser    Cynthia      F     Animation          Lead Animator
# 2  10552    Leslie       Jean      F           Art                 Artist
#
#    Salary Performance
# 0   67000     Average
# 1   80000        Good
# 2   45250     Average

# %%
# 5) display all column types
print("Jhair Morales Gonzalez")
print(gameSalary.dtypes)
# Out:
# Jhair Morales Gonzalez
# ID              int64
# Last Name      object
# First Name     object
# Gender         object
# Department     object
# Title          object
# Salary          int64
# Performance    object
# dtype: object

# %%
# 6) Change Salary data type to float
gameSalary['Salary'] = gameSalary['Salary'].astype(float)
gameSalary.dtypes
# Out:
# ID               int64
# Last Name       object
# First Name      object
# Gender          object
# Department      object
# Title           object
# Salary         float64
# Performance     object
# dtype: object

# %%
# 7) Use basic info() 
print('Jhair Morales Gonzalez')
gameSalary.info()
# Out:
# Jhair Morales Gonzalez
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           93 non-null     int64
#  1   Last Name    93 non-null     object
#  2   First Name   93 non-null     object
#  3   Gender       93 non-null     object
#  4   Department   93 non-null     object
#  5   Title        93 non-null     object
#  6   Salary       93 non-null     float64
#  7   Performance  93 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.9+ KB

# %%
# 8) show Salary column summary
print('Jhair Morales Gonzalez')
gameSalary['Salary'].describe()
# Out:
# Jhair Morales Gonzalez
# count        93.000000
# mean      62346.182796
# std       18004.230095
# min       35000.000000
# 25%       50000.000000
# 50%       60000.000000
# 75%       70125.000000
# max      120000.000000
# Name: Salary, dtype: float64

# %%
# 9) show mean, min, max of Salary
#print('mean', gameSalary["Salary"].mean())
#print('min', gameSalary["Salary"].min())
#print('Salary mean:', gameSalary.Salary.mean())
print('Jhair Morales Gonzalez')

print("Mean: $",format(gameSalary['Salary'].mean(),'.2f'))
print("Min: $",format (gameSalary['Salary'].min(), '.2f'))
print("Max: $",format (gameSalary['Salary'].max(),'.2f'))

res1 = gameSalary['Salary'].mean()
res2 = gameSalary['Salary'].min()
print('Average Salary:  $' , format(res1,'.2f'))
print('Lowest Salary:   $' , format(res2,'.2f'))
# Out:
# Jhair Morales Gonzalez
# Mean: $ 62346.18
# Min: $ 35000.00
# Max: $ 120000.00
# Average Salary:  $ 62346.18
# Lowest Salary:   $ 35000.00

# %%
# 10) Show Female Programmer and sorting by using  .sort_values(by='Salary')




res.head(3)
# Out:
#        ID Last Name First Name Gender   Department       Title  Salary  \
# 41  18223    Titley      Kathy      F  Programming  Programmer   50000
# 89  26813    Denver        Jan      F  Programming  Programmer   58400
# 46  19757      Dill     Jeanne      F  Programming  Programmer   60125
#
#    Performance
# 41     Average
# 89     Average
# 46     Average

# %%
# 11) Display Female employees's average salary




print('Average Salary:  $' , format(res,'.2f'))
# Out:
# Average Salary:  $ 62426.39

# %%
# 12) Display Female Programmer's average salary
print('Jhair Morales Gonzalez')
femaleProgrammer = gameSalary[(gameSalary['Gender'] == 'F') & (gameSalary['Title'] == 'Programmer')]
res = femaleProgrammer['Salary'].mean()
print('Average Salary: $',format(res, '.2f'))
# Out:
# Jhair Morales Gonzalez
# Average Salary: $ 72500.77

# %%
# 13) Only diplay three columns: ID, Salary, Performance 
print('Jhair Morales Gonzalez')
gameSalary[['ID', 'Salary', 'Performance']].head(3)
# Out:
# Jhair Morales Gonzalez
#       ID   Salary Performance
# 0  10000  67000.0     Average
# 1  10387  80000.0        Good
# 2  10552  45250.0     Average

# %%
# 14)
# A) Show all Titles name with no duplicate,       
# B) Display the title names as flowing format    

res = gameSalary['Title'].unique()
print(res)

print('\nTitles')
print('----------')
for name in res:
    print(name)
# Out:
# ['Senior Sound Designer' 'Lead Animator' 'Artist' 'Programmer'
#  'Senior Game Designer' 'Senior Programmer' 'QA Tester' 'Senior Animator'
#  'Animator' 'Sound Designer' 'Senior QA Tester' 'Senior Artist'
#  'Game Designer' 'Executive Producer' 'Producer: Product Manager'
#  'Lead Artist' 'Lead Sound Designer' 'Lead Game Designer' 'Lead QA Tester'
#  'Lead Programmer']
#
# Titles
# ----------
# Senior Sound Designer
# Lead Animator
# Artist
# Programmer
# Senior Game Designer
# Senior Programmer
# QA Tester
# Senior Animator
# Animator
# Sound Designer
# Senior QA Tester
# Senior Artist
# Game Designer
# Executive Producer
# Producer: Product Manager
# Lead Artist
# Lead Sound Designer
# Lead Game Designer
# Lead QA Tester
# Lead Programmer

# %%
# 15) Create a bar chart to compare average Salary by gender. 
# .groupby('')      
# .mean()      
# plot    
print('Jhair Morales Gonzalez')
gameSalary.groupby('Gender')['Salary'].mean().plot(kind='bar')
# Out:
# Jhair Morales Gonzalez
# <Axes: xlabel='Gender'>

# %%
# 16)+17) 
# Create a bar chart to compare average Salary by Department. 
# .groupby('')      
# .mean()      
# plot    
print('Jhair Morales Gonzalez')
gameSalary.groupby('Department')['Salary'].mean().plot(kind='bar')
# Out:
# Jhair Morales Gonzalez
# <Axes: xlabel='Department'>

# %%
# 17) + 18) Show the number of employees for each performance level 
# and create pie chart (and show percentage)
deptCounts = gameSalary.groupby('Department').size().sort_values(ascending = False)
deptCounts.plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
# 19) + 20) 
# Show the number of employee for each department,
# and sorted by the values from hight to low
# And plot the result as bar chart

#  .groupby('Department') or df.Department.value_counts() 
#  .sort_values(ascending=False)  
#  .plot 
gameSalary['Performance'].value_counts().plot(kind='pie',title='Performance per level',autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Performance per level'}, ylabel='count'>
